# %% [markdown]
# <a href="https://colab.research.google.com/github/cicerohenjr/alura-imersao-dados-python/blob/main/aula00_fundamentos/aula00_introducao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐍 Aula 0: Fundamentos do Python
# Nesta aula preparatória, exploramos a sintaxe básica do Python, tipos de dados e convenções de código.
#
# ## 1. Variáveis e Tipos de Dados
# Aprendemos que o Python é uma linguagem de **alto nível** (próxima da linguagem humana) e fortemente tipada.
# * **Strings (Texto):** Sempre entre aspas (`"Texto"`).
# * **Inteiros (Números):** Sem aspas, permitem operações matemáticas.

# %% [markdown]
# # Criando variáveis para armazenar dados na memória
# nome = "Guilherme"
# idade = 28
#
# # O comando print exibe a informação na tela
# print(nome)
# print(idade)
#
# # Tentativa de erro proposital (NameError)
# # print(Guilherme) # Isso daria erro pois sem aspas o Python acha que é uma variável

# %% [markdown]
# ## 2. Boas Práticas: Snake Case
# Para nomes de variáveis compostas, o Python utiliza o padrão **Snake Case** (palavras separadas por _), diferente do CamelCase usado em Java ou JavaScript. Isso melhora a legibilidade, conforme o "Zen do Python".

# %% [markdown]
# # Exemplo de Snake Case
# cor_favorita = "Cinza"
# banda_favorita = "U2"
#
# print(f"Minha banda favorita é {banda_favorita} e gosto da cor {cor_favorita}")

# %% [markdown]
# ## 3. Operações com Variáveis
# Variáveis numéricas podem sofrer alterações ao longo do código.

# %% [markdown]
# saldo = 5000
# recebeu_trabalho = 2000
#
# # Atualizando o valor da variável (Atribuição)
# saldo = saldo + recebeu_trabalho
#
# print(f"Saldo atualizado: {saldo}")

# %% [markdown]
# ## 4. Estruturas Condicionais (if/else)
# Aqui aprendemos o conceito crucial de **Identação**.
# * No Python, não usamos chaves `{}` para separar blocos. Usamos **espaços** (recuo).
# * Tudo que está "dentro" do `if` precisa estar recuado para funcionar.

# %%
idade_carteira = 18

print("--- Verificação de Habilitação ---")

# A lógica: Se a idade for maior ou igual (>=) a 18
if idade_carteira >= 18:
  print("Pode dirigir") # O recuo aqui indica que este código pertence ao IF
else:
  print("Não pode dirigir")
# Out:
# --- Verificação de Habilitação ---
# Pode dirigir
